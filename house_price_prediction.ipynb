# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('train.csv')

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.shape
# Out:
# (1460, 81)

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
df1 = pd.read_csv('test.csv')

# %%
df2 = pd.concat([df,df1],ignore_index=True, axis=0)

# %%
df2.shape
# Out:
# (2919, 81)

# %%
df2['SalePrice'].sample(5)
# Out:
# 1407    112000.0
# 2514         NaN
# 2259         NaN
# 1576         NaN
# 2413         NaN
# Name: SalePrice, dtype: float64

# %%
df2.drop('Id', inplace=True, axis = True)

# %%
df2.shape
# Out:
# (2919, 80)

# %%
df2.columns
# Out:
# Index(['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street', 'Alley',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
# ...

# %%
df2.dtypes
# Out:
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
# Street            object
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice        float64
# Length: 80, dtype: object

# %%
for col in df2:
    x = df2[col].isnull().sum()
    if x > 200:
        print(f'{col} : {x}')
# Out:
# LotFrontage : 486
# Alley : 2721
# FireplaceQu : 1420
# PoolQC : 2909
# Fence : 2348
# MiscFeature : 2814
# SalePrice : 1459

# %%
df2.drop(['SalePrice','MiscFeature','Fence','PoolQC','FireplaceQu','Alley'], axis = 1, inplace=True)

# %%
df2.shape
# Out:
# (2919, 74)

# %%
for col in df2:
    x = df2[col].isnull().sum()
    if x > 100:
        print(f'{col} : {x}')
        print(df2[col].sample)
# Out:
# LotFrontage : 486
# <bound method NDFrame.sample of 0        65.0
# 1        80.0
# 2        68.0
# 3        60.0
# 4        84.0
#         ...
# 2914     21.0
# 2915     21.0
# 2916    160.0
# 2917     62.0
# 2918     74.0
# Name: LotFrontage, Length: 2919, dtype: float64>
# GarageType : 157
# <bound method NDFrame.sample of 0        Attchd
# 1        Attchd
# 2        Attchd
# 3        Detchd
# 4        Attchd
#          ...
# 2914        NaN
# 2915    CarPort
# 2916     Detchd
# 2917        NaN
# 2918     Attchd
# Name: GarageType, Length: 2919, dtype: object>
# GarageYrBlt : 159
# <bound method NDFrame.sample of 0       2003.0
# 1       1976.0
# 2       2001.0
# 3       1998.0
# 4       2000.0
#          ...
# 2914       NaN
# 2915    1970.0
# 2916    1960.0
# 2917       NaN
# 2918    1993.0
# Name: GarageYrBlt, Length: 2919, dtype: float64>
# GarageFinish : 159
# <bound method NDFrame.sample of 0       RFn
# 1       RFn
# 2       RFn
# 3       Unf
# 4       RFn
#        ...
# ...

# %%
df2['SalePrice']=df['SalePrice']

# %%
df2['SalePrice'].tail()
# Out:
# 2914   NaN
# 2915   NaN
# 2916   NaN
# 2917   NaN
# 2918   NaN
# Name: SalePrice, dtype: float64

# %%
df2['SalePrice'].dtypes
# Out:
# dtype('float64')

# %%
for col in df2:
    if df2[col].dtypes == 'object':
        df2[col] = df2[col].fillna(df2[col].mode()[0])
    if df2[col].dtypes == 'float':
        df2[col] = df2[col].fillna(df2[col].mean())

# %%
df2.isnull().sum()
# Out:
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
# Street           0
#                 ..
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# SalePrice        0
# Length: 75, dtype: int64

# %%
for col in df2:
    if df2[col].isnull().sum() > 0:
        print(col)

# %%
import seaborn as sns

# %%
sns.heatmap(df2.isnull(),yticklabels=False,cbar=False)
# Out:
# <AxesSubplot:>

# %%
# Handle categorical features
cat_cols = []
for col in df2:
    if df2[col].dtypes == 'object':
        cat_cols.append(col)

# %%
cat_cols
# Out:
# ['MSZoning',
#  'Street',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'SaleType',
#  'SaleCondition']

# %%
len(cat_cols)
# Out:
# 38

# %%
df2.shape
# Out:
# (2919, 75)

# %%
df2
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0             60       RL         65.0     8450   Pave      Reg         Lvl
# 1             20       RL         80.0     9600   Pave      Reg         Lvl
# 2             60       RL         68.0    11250   Pave      IR1         Lvl
# 3             70       RL         60.0     9550   Pave      IR1         Lvl
# 4             60       RL         84.0    14260   Pave      IR1         Lvl
# ...          ...      ...          ...      ...    ...      ...         ...
# 2914         160       RM         21.0     1936   Pave      Reg         Lvl
# 2915         160       RM         21.0     1894   Pave      Reg         Lvl
# 2916          20       RL        160.0    20000   Pave      Reg         Lvl
# 2917          85       RL         62.0    10441   Pave      Reg         Lvl
# 2918          60       RL         74.0     9627   Pave      Reg         Lvl
#
# ...

# %%
df3 = df2.copy()

# %%
df3.shape
# Out:
# (2919, 75)

# %%
df3
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0             60       RL         65.0     8450   Pave      Reg         Lvl
# 1             20       RL         80.0     9600   Pave      Reg         Lvl
# 2             60       RL         68.0    11250   Pave      IR1         Lvl
# 3             70       RL         60.0     9550   Pave      IR1         Lvl
# 4             60       RL         84.0    14260   Pave      IR1         Lvl
# ...          ...      ...          ...      ...    ...      ...         ...
# 2914         160       RM         21.0     1936   Pave      Reg         Lvl
# 2915         160       RM         21.0     1894   Pave      Reg         Lvl
# 2916          20       RL        160.0    20000   Pave      Reg         Lvl
# 2917          85       RL         62.0    10441   Pave      Reg         Lvl
# 2918          60       RL         74.0     9627   Pave      Reg         Lvl
#
# ...

# %% [markdown]
# ###

# %%
for col in cat_cols:
    df3 = pd.get_dummies(df3[col],drop_first=True)
    df3.drop([col], inplace=True, axis =1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-4557e0386adf> in <module>
#       1 for col in cat_cols:
#       2     df3 = pd.get_dummies(df3[col],drop_first=True)
# ----> 3     df3.drop([col], inplace=True, axis =1)
#
# D:\anaconda3\envs\deep\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4313             level=level,
#    4314             inplace=inplace,
# -> 4315             errors=errors,
#    4316         )
#    4317
#
# D:\anaconda3\envs\deep\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ...

# %%
df3
# Out:
#       FV  RH  RL  RM
# 0      0   0   1   0
# 1      0   0   1   0
# 2      0   0   1   0
# 3      0   0   1   0
# 4      0   0   1   0
# ...   ..  ..  ..  ..
# 2914   0   0   0   1
# 2915   0   0   0   1
# 2916   0   0   1   0
# 2917   0   0   1   0
# 2918   0   0   1   0
#
# [2919 rows x 4 columns]

# %%
df2
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0             60       RL         65.0     8450   Pave      Reg         Lvl
# 1             20       RL         80.0     9600   Pave      Reg         Lvl
# 2             60       RL         68.0    11250   Pave      IR1         Lvl
# 3             70       RL         60.0     9550   Pave      IR1         Lvl
# 4             60       RL         84.0    14260   Pave      IR1         Lvl
# ...          ...      ...          ...      ...    ...      ...         ...
# 2914         160       RM         21.0     1936   Pave      Reg         Lvl
# 2915         160       RM         21.0     1894   Pave      Reg         Lvl
# 2916          20       RL        160.0    20000   Pave      Reg         Lvl
# 2917          85       RL         62.0    10441   Pave      Reg         Lvl
# 2918          60       RL         74.0     9627   Pave      Reg         Lvl
#
# ...

# %%
df3 = df2.copy()

# %%
df3
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0             60       RL         65.0     8450   Pave      Reg         Lvl
# 1             20       RL         80.0     9600   Pave      Reg         Lvl
# 2             60       RL         68.0    11250   Pave      IR1         Lvl
# 3             70       RL         60.0     9550   Pave      IR1         Lvl
# 4             60       RL         84.0    14260   Pave      IR1         Lvl
# ...          ...      ...          ...      ...    ...      ...         ...
# 2914         160       RM         21.0     1936   Pave      Reg         Lvl
# 2915         160       RM         21.0     1894   Pave      Reg         Lvl
# 2916          20       RL        160.0    20000   Pave      Reg         Lvl
# 2917          85       RL         62.0    10441   Pave      Reg         Lvl
# 2918          60       RL         74.0     9627   Pave      Reg         Lvl
#
# ...

# %%
df_temp = pd.get_dummies(df3, columns=cat_cols, drop_first=True)

# %%
df_temp
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0             60         65.0     8450            7            5       2003
# 1             20         80.0     9600            6            8       1976
# 2             60         68.0    11250            7            5       2001
# 3             70         60.0     9550            7            5       1915
# 4             60         84.0    14260            8            5       2000
# ...          ...          ...      ...          ...          ...        ...
# 2914         160         21.0     1936            4            7       1970
# 2915         160         21.0     1894            4            5       1970
# 2916          20        160.0    20000            5            7       1960
# 2917          85         62.0    10441            5            5       1992
# 2918          60         74.0     9627            7            5       1993
#
# ...

# %%
for col in df_temp:
    type = df_temp[col].dtypes
    if type == 'float':
        print(col)
# Out:
# LotFrontage
# MasVnrArea
# BsmtFinSF1
# BsmtFinSF2
# BsmtUnfSF
# TotalBsmtSF
# BsmtFullBath
# BsmtHalfBath
# GarageYrBlt
# GarageCars
# GarageArea
# SalePrice

# %%
for col in df_temp:
    if col not in cat_cols:
        print(col)
# Out:
# MSSubClass
# LotFrontage
# LotArea
# OverallQual
# OverallCond
# YearBuilt
# YearRemodAdd
# MasVnrArea
# BsmtFinSF1
# BsmtFinSF2
# BsmtUnfSF
# TotalBsmtSF
# 1stFlrSF
# 2ndFlrSF
# LowQualFinSF
# GrLivArea
# BsmtFullBath
# BsmtHalfBath
# FullBath
# HalfBath
# BedroomAbvGr
# KitchenAbvGr
# TotRmsAbvGrd
# Fireplaces
# GarageYrBlt
# GarageCars
# GarageArea
# WoodDeckSF
# OpenPorchSF
# EnclosedPorch
# 3SsnPorch
# ScreenPorch
# PoolArea
# MiscVal
# MoSold
# YrSold
# SalePrice
# MSZoning_FV
# MSZoning_RH
# MSZoning_RL
# MSZoning_RM
# Street_Pave
# LotShape_IR2
# LotShape_IR3
# LotShape_Reg
# LandContour_HLS
# LandContour_Low
# LandContour_Lvl
# Utilities_NoSeWa
# LotConfig_CulDSac
# LotConfig_FR2
# LotConfig_FR3
# LotConfig_Inside
# LandSlope_Mod
# LandSlope_Sev
# Neighborhood_Blueste
# Neighborhood_BrDale
# Neighborhood_BrkSide
# Neighborhood_ClearCr
# Neighborhood_CollgCr
# Neighborhood_Crawfor
# Neighborhood_Edwards
# Neighborhood_Gilbert
# Neighborhood_IDOTRR
# Neighborhood_MeadowV
# ...

# %%
df_temp.shape
# Out:
# (2919, 233)

# %%
df.shape
# Out:
# (1460, 81)

# %%
df.tail()
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 1455         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1456         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1457         Lvl    AllPub  ...        0    NaN  GdPrv        Shed    2500
# 1458         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1459         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
cols_to_scale = []
for col in df_temp:
    if df_temp[col].dtypes == 'float' or df_temp[col].dtypes == 'int':
        cols_to_scale.append(col)

# %%
cols_to_scale
# Out:
# ['LotFrontage',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'GarageYrBlt',
#  'GarageCars',
#  'GarageArea',
#  'SalePrice']

# %%
from sklearn.preprocessing import MinMaxScaler
minmax = MinMaxScaler()
df_temp[cols_to_scale] = minmax.fit_transform(df_temp[cols_to_scale])

# %%
for col in df_temp:
    print(df_temp[col].dtypes)
# Out:
# int64
# float64
# int64
# int64
# int64
# int64
# int64
# float64
# float64
# float64
# float64
# float64
# int64
# int64
# int64
# int64
# float64
# float64
# int64
# int64
# int64
# int64
# int64
# int64
# float64
# float64
# float64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# float64
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# uint8
# ...

# %%
for col in df_temp:
    if df_temp[col].dtypes == 'int64':
        print(df_temp[col].sample(5))
# Out:
# 1061    30
# 1757    20
# 738     90
# 2179    90
# 332     20
# Name: MSSubClass, dtype: int64
# 2596     7777
# 273      9600
# 306     13474
# 2369     2280
# 117      8536
# Name: LotArea, dtype: int64
# 926     8
# 1056    7
# 2204    5
# 2001    7
# 1639    7
# Name: OverallQual, dtype: int64
# 660     7
# 1011    5
# 376     5
# 1773    4
# 148     5
# Name: OverallCond, dtype: int64
# 1138    1977
# 1164    1978
# 1726    1990
# 2591    2006
# 2648    1967
# Name: YearBuilt, dtype: int64
# 2314    2006
# 1682    2003
# 1953    1988
# 1499    2005
# 1296    1963
# Name: YearRemodAdd, dtype: int64
# 991      916
# 790     1145
# 1600     540
# 463      849
# 1873     990
# Name: 1stFlrSF, dtype: int64
# 2337      0
# 1743      0
# 2313    850
# 1680      0
# 2665      0
# Name: 2ndFlrSF, dtype: int64
# 1678    0
# 1066    0
# 1917    0
# 639     0
# 2409    0
# Name: LowQualFinSF, dtype: int64
# 635     3395
# 2783     960
# 1865    1720
# 378     1856
# 2615    1024
# ...

# %%
train = df_temp[:1460]

# %%
train.tail()
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 1455          60     0.140411     7917            6            5       1999
# 1456          20     0.219178    13175            6            6       1978
# 1457          70     0.154110     9042            7            9       1941
# 1458          20     0.160959     9717            5            6       1950
# 1459          20     0.184932     9937            5            6       1965
#
#       YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  ...  SaleType_ConLI  \
# 1455          2000    0.000000    0.000000    0.000000  ...               0
# 1456          1988    0.074375    0.139972    0.106815  ...               0
# 1457          2006    0.000000    0.048724    0.000000  ...               0
# 1458          1996    0.000000    0.008682    0.674312  ...               0
# 1459          1965    0.000000    0.147059    0.190039  ...               0
#
# ...

# %%
test = df_temp[1460:]

# %%
test.head()
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 1460          20     0.202055    11622            5            6       1961
# 1461          20     0.205479    14267            6            6       1958
# 1462          60     0.181507    13830            5            5       1997
# 1463          60     0.195205     9978            6            6       1998
# 1464         120     0.075342     5005            8            5       1992
#
#       YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  ...  SaleType_ConLI  \
# 1460          1961      0.0000    0.082920    0.094364  ...               0
# 1461          1958      0.0675    0.163536    0.000000  ...               0
# 1462          1998      0.0000    0.140149    0.000000  ...               0
# 1463          1998      0.0125    0.106662    0.000000  ...               0
# 1464          1992      0.0000    0.046598    0.000000  ...               0
#
# ...

# %%
df1.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
ytrain = train['SalePrice']

# %%
xtrain = train.drop('SalePrice', axis = 1)

# %%
xtrain.shape
# Out:
# (1460, 232)

# %%
ytrain.shape
# Out:
# (1460,)

# %%
test.shape
# Out:
# (1459, 233)

# %%
test.dropna(inplace=True)
# Out:
# D:\anaconda3\envs\deep\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
test.shape
# Out:
# (1459, 233)

# %%
test['SalePrice'].sample(5)
# Out:
# 2707    0.202779
# 2413    0.202779
# 1471    0.202779
# 2798    0.202779
# 2918    0.202779
# Name: SalePrice, dtype: float64

# %%
test.drop(['SalePrice'],inplace=True, axis = 1 )
# Out:
# D:\anaconda3\envs\deep\lib\site-packages\pandas\core\frame.py:4315: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
test.shape
# Out:
# (1459, 232)

# %%
df1.shape
# Out:
# (1459, 80)

# %%
df1.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
test.head()
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 1460          20     0.202055    11622            5            6       1961
# 1461          20     0.205479    14267            6            6       1958
# 1462          60     0.181507    13830            5            5       1997
# 1463          60     0.195205     9978            6            6       1998
# 1464         120     0.075342     5005            8            5       1992
#
#       YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  ...  SaleType_ConLI  \
# 1460          1961      0.0000    0.082920    0.094364  ...               0
# 1461          1958      0.0675    0.163536    0.000000  ...               0
# 1462          1998      0.0000    0.140149    0.000000  ...               0
# 1463          1998      0.0125    0.106662    0.000000  ...               0
# 1464          1992      0.0000    0.046598    0.000000  ...               0
#
# ...

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LeakyReLU, PReLU, ELU
from keras.layers import Dropout

# %%
classifier = Sequential()

# %%
classifier.add(Dense(50,kernel_initializer ='he_uniform' , activation = 'relu',input_dim = 232))
classifier.add(Dense(25, kernel_initializer = 'he_uniform',activation='relu'))
classifier.add(Dense(50, kernel_initializer = 'he_uniform',activation='relu'))
classifier.add(Dense(1, kernel_initializer = 'he_uniform'))

# %%
classifier.compile(loss = 'mse', optimizer = 'Adamax')

# %%
ytrain = df['SalePrice']

# %%
model_history=classifier.fit(xtrain, ytrain,validation_split=0.20, batch_size = 10, epochs = 100)
# Out:
# Epoch 1/100
# 117/117 [==============================] - 2s 8ms/step - loss: 35493171200.0000 - val_loss: 26251560960.0000
# Epoch 2/100
# 117/117 [==============================] - 0s 3ms/step - loss: 13650514944.0000 - val_loss: 6930298368.0000
# Epoch 3/100
# 117/117 [==============================] - 0s 3ms/step - loss: 9399094272.0000 - val_loss: 6273784832.0000
# Epoch 4/100
# 117/117 [==============================] - 0s 3ms/step - loss: 8254154240.0000 - val_loss: 5896572416.0000
# Epoch 5/100
# 117/117 [==============================] - 0s 3ms/step - loss: 7458693632.0000 - val_loss: 5634100224.0000
# Epoch 6/100
# 117/117 [==============================] - 0s 3ms/step - loss: 6708474368.0000 - val_loss: 5399092736.0000
# Epoch 7/100
# 117/117 [==============================] - 0s 3ms/step - loss: 6173514752.0000 - val_loss: 5226921984.0000
# Epoch 8/100
# 117/117 [==============================] - 0s 3ms/step - loss: 5664451072.0000 - val_loss: 5118885376.0000
# ...

# %%
ypred = classifier.predict(test)

# %%
ypred = pd.DataFrame(ypred)

# %%
ypred.shape
# Out:
# (1459, 1)

# %%
ypred
# Out:
#                   0
# 0     127400.976562
# 1     167078.265625
# 2     184590.187500
# 3     192293.093750
# 4     176376.859375
# ...             ...
# 1454   99074.546875
# 1455  100983.929688
# 1456  191686.812500
# 1457  124623.312500
# 1458  219266.062500
#
# [1459 rows x 1 columns]

# %%
test.shape
# Out:
# (1459, 232)

# %%
id = df1['Id']

# %%
submit = pd.concat([id,ypred], axis = 1 )

# %%
submit.head()
# Out:
#      Id              0
# 0  1461  127400.976562
# 1  1462  167078.265625
# 2  1463  184590.187500
# 3  1464  192293.093750
# 4  1465  176376.859375

# %%
submit.columns = ['Id' , 'SalePrice']

# %%
submit.head()
# Out:
#      Id      SalePrice
# 0  1461  127400.976562
# 1  1462  167078.265625
# 2  1463  184590.187500
# 3  1464  192293.093750
# 4  1465  176376.859375

# %%
submit.tail()
# Out:
#         Id      SalePrice
# 1454  2915   99074.546875
# 1455  2916  100983.929688
# 1456  2917  191686.812500
# 1457  2918  124623.312500
# 1458  2919  219266.062500

# %%
submission_file = submit.to_csv('submission_file.csv', encoding='utf-8', index= False)
